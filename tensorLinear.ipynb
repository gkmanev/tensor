# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
#from tensorflow.keras.optimizers import *
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import *
import datetime
import seaborn as sns
import tensorflow as tf
import matplotlib.dates as mdates

## timestamp dependencies
from datetime import datetime

## visualisation dependencies
import matplotlib.pyplot as plt
series = pd.read_csv('data.csv')
series.drop_duplicates(subset='created', inplace=True)
series['created'] = pd.to_datetime(series['created'])
#series.set_index('created', inplace=True)

#df_resampled = series.resample('1H').asfreq()

date_time = pd.to_datetime(series.pop('created'), format='%d.%m.%Y %H:%M:%S')

timestamp_s = date_time.map(pd.Timestamp.timestamp)

day = 24*60*60
year = (365.2425)*day

series['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
series['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
# series['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
# series['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))


column_indices = {name: i for i, name in enumerate(series.columns)}

n = len(series)
train_df = series[0:int(n*0.7)]
val_df = series[int(n*0.7):int(n*0.9)]
test_df = series[int(n*0.9):]

num_features = series.shape[1]

train_mean = train_df.mean()
train_std = train_df.std()

train_df = (train_df - train_mean) / train_std
val_df = (val_df - train_mean) / train_std
test_df = (test_df - train_mean) / train_std



df_std = (series - train_mean) / train_std
df_std = df_std.melt(var_name='Column', value_name='Normalized')
# plt.figure(figsize=(12, 6))
# ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
# _ = ax.set_xticklabels(series.keys(), rotation=90)

# %%
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df=train_df, val_df=val_df, test_df=test_df,
               label_columns=None):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df

    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
  @property
  def train(self):
    return self.make_dataset(self.train_df)

  @property
  def val(self):
    return self.make_dataset(self.val_df)

  @property
  def test(self):
    return self.make_dataset(self.test_df)

  @property
  def example(self):
    """Get and cache an example batch of `inputs, labels` for plotting."""
    result = getattr(self, '_example', None)
    if result is None:
      # No example batch was found, so get one from the `.train` dataset
      result = next(iter(self.train))
      # And cache it for next time
      self._example = result
    return result

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])
  
  def split_window(self, features):
      inputs = features[:, self.input_slice, :]
      labels = features[:, self.labels_slice, :]
      if self.label_columns is not None:
          labels = tf.stack(
              [labels[:, :, self.column_indices[name]] for name in self.label_columns],
              axis=-1
          )
      inputs.set_shape([None, self.input_width, None])
      labels.set_shape([None, self.label_width, None])
      return inputs, labels
  
  def make_dataset(self, data):
    data = np.array(data, dtype=np.float32)
    ds = tf.keras.utils.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=self.total_window_size,
        sequence_stride=1,
        shuffle=True,
        batch_size=32,)

    ds = ds.map(self.split_window)

    return ds 

  def plot(self, model=None, plot_col='value', max_subplots=3):
      inputs, labels = self.example
      plt.figure(figsize=(12, 8))
      plot_col_index = self.column_indices[plot_col]
      max_n = min(max_subplots, len(inputs))
      x = self.train_df.index  # Assuming the index represents the date and time

      for n in range(max_n):
          plt.subplot(max_n, 1, n+1)
          plt.ylabel(f'{plot_col} [normed]')
          plt.plot(x[self.input_indices], inputs[n, :, plot_col_index],
                  label='Inputs', marker='.', zorder=-10)

          if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
          else:
              label_col_index = plot_col_index

          if label_col_index is not None:
              plt.scatter(x[self.label_indices], labels[n, :, label_col_index],
                          edgecolors='k', label='Labels', c='#2ca02c', s=64)

          if model is not None:
              predictions = model(inputs)
              prediction_col_index = self.label_columns_indices.get(plot_col, None)
              if prediction_col_index is not None:
                  plt.scatter(x[self.label_indices], predictions[n, :, prediction_col_index],
                              marker='X', edgecolors='k', label='Predictions',
                              c='#ff7f0e', s=64)

          if n == 0:
              plt.legend()

      plt.xlabel('Date and Time')
      plt.xticks(rotation=45)
      # plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
      # plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
      plt.show()

# %%
class Baseline(tf.keras.Model):
  def __init__(self, label_index=None):
    super().__init__()
    self.label_index = label_index

  def call(self, inputs):
    if self.label_index is None:
      return inputs
    result = inputs[:, :, self.label_index]
    return result[:, :, tf.newaxis]

# %%
wide_window = WindowGenerator(
    input_width=24, label_width=24, shift=1,
    label_columns=['value'])

# %%
linear = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1)
])

# %%
MAX_EPOCHS = 50

def compile_and_fit(model, window, patience=2):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  model.compile(loss=tf.keras.losses.MeanSquaredError(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=[tf.keras.metrics.MeanAbsoluteError()])

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %%
history = compile_and_fit(linear, wide_window)

val_performance['Linear'] = linear.evaluate(wide_window.val)
performance['Linear'] = linear.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 39/39 [==============================] - 2s 15ms/step - loss: 1.5252 - mean_absolute_error: 1.0088 - val_loss: 1.9140 - val_mean_absolute_error: 1.0601
# Epoch 2/50
# 39/39 [==============================] - 0s 9ms/step - loss: 1.4139 - mean_absolute_error: 0.9722 - val_loss: 1.7637 - val_mean_absolute_error: 1.0185
# Epoch 3/50
# 39/39 [==============================] - 1s 12ms/step - loss: 1.3102 - mean_absolute_error: 0.9364 - val_loss: 1.6279 - val_mean_absolute_error: 0.9788
# Epoch 4/50
# 39/39 [==============================] - 0s 7ms/step - loss: 1.2140 - mean_absolute_error: 0.9016 - val_loss: 1.5036 - val_mean_absolute_error: 0.9405
# Epoch 5/50
# 39/39 [==============================] - 0s 9ms/step - loss: 1.1244 - mean_absolute_error: 0.8681 - val_loss: 1.3832 - val_mean_absolute_error: 0.9027
# Epoch 6/50
# 39/39 [==============================] - 0s 5ms/step - loss: 1.0412 - mean_absolute_error: 0.8353 - val_loss: 1.2769 - val_mean_absolute_error: 0.8666
# Epoch 7/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.9639 - mean_absolute_error: 0.8037 - val_loss: 1.1743 - val_mean_absolute_error: 0.8309
# Epoch 8/50
# 39/39 [==============================] - 1s 11ms/step - loss: 0.8921 - mean_absolute_error: 0.7730 - val_loss: 1.0821 - val_mean_absolute_error: 0.7967
# Epoch 9/50
# 39/39 [==============================] - 0s 8ms/step - loss: 0.8259 - mean_absolute_error: 0.7434 - val_loss: 0.9930 - val_mean_absolute_error: 0.7629
# Epoch 10/50
# 39/39 [==============================] - 1s 11ms/step - loss: 0.7647 - mean_absolute_error: 0.7152 - val_loss: 0.9114 - val_mean_absolute_error: 0.7305
# Epoch 11/50
# 39/39 [==============================] - 1s 14ms/step - loss: 0.7082 - mean_absolute_error: 0.6878 - val_loss: 0.8380 - val_mean_absolute_error: 0.6992
# Epoch 12/50
# 39/39 [==============================] - 1s 10ms/step - loss: 0.6561 - mean_absolute_error: 0.6616 - val_loss: 0.7694 - val_mean_absolute_error: 0.6687
# Epoch 13/50
# 39/39 [==============================] - 1s 14ms/step - loss: 0.6081 - mean_absolute_error: 0.6365 - val_loss: 0.7048 - val_mean_absolute_error: 0.6393
# Epoch 14/50
# 39/39 [==============================] - 1s 12ms/step - loss: 0.5640 - mean_absolute_error: 0.6128 - val_loss: 0.6469 - val_mean_absolute_error: 0.6118
# Epoch 15/50
# 39/39 [==============================] - 1s 15ms/step - loss: 0.5236 - mean_absolute_error: 0.5903 - val_loss: 0.5925 - val_mean_absolute_error: 0.5856
# Epoch 16/50
# 39/39 [==============================] - 1s 13ms/step - loss: 0.4866 - mean_absolute_error: 0.5689 - val_loss: 0.5441 - val_mean_absolute_error: 0.5610
# Epoch 17/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.4527 - mean_absolute_error: 0.5485 - val_loss: 0.4996 - val_mean_absolute_error: 0.5373
# Epoch 18/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.4219 - mean_absolute_error: 0.5293 - val_loss: 0.4566 - val_mean_absolute_error: 0.5142
# Epoch 19/50
# 39/39 [==============================] - 0s 10ms/step - loss: 0.3936 - mean_absolute_error: 0.5111 - val_loss: 0.4199 - val_mean_absolute_error: 0.4929
# Epoch 20/50
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3681 - mean_absolute_error: 0.4940 - val_loss: 0.3858 - val_mean_absolute_error: 0.4725
# Epoch 21/50
# 39/39 [==============================] - 1s 11ms/step - loss: 0.3449 - mean_absolute_error: 0.4781 - val_loss: 0.3547 - val_mean_absolute_error: 0.4533
# Epoch 22/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3238 - mean_absolute_error: 0.4633 - val_loss: 0.3268 - val_mean_absolute_error: 0.4350
# Epoch 23/50
# 39/39 [==============================] - 1s 9ms/step - loss: 0.3048 - mean_absolute_error: 0.4497 - val_loss: 0.3005 - val_mean_absolute_error: 0.4181
# Epoch 24/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2877 - mean_absolute_error: 0.4370 - val_loss: 0.2778 - val_mean_absolute_error: 0.4029
# Epoch 25/50
# 39/39 [==============================] - 1s 18ms/step - loss: 0.2724 - mean_absolute_error: 0.4250 - val_loss: 0.2573 - val_mean_absolute_error: 0.3886
# Epoch 26/50
# 39/39 [==============================] - 0s 9ms/step - loss: 0.2587 - mean_absolute_error: 0.4138 - val_loss: 0.2386 - val_mean_absolute_error: 0.3754
# Epoch 27/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2464 - mean_absolute_error: 0.4036 - val_loss: 0.2224 - val_mean_absolute_error: 0.3636
# Epoch 28/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2355 - mean_absolute_error: 0.3941 - val_loss: 0.2073 - val_mean_absolute_error: 0.3521
# Epoch 29/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2257 - mean_absolute_error: 0.3856 - val_loss: 0.1942 - val_mean_absolute_error: 0.3416
# Epoch 30/50
# 39/39 [==============================] - 0s 8ms/step - loss: 0.2171 - mean_absolute_error: 0.3776 - val_loss: 0.1824 - val_mean_absolute_error: 0.3320
# Epoch 31/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2096 - mean_absolute_error: 0.3704 - val_loss: 0.1723 - val_mean_absolute_error: 0.3234
# Epoch 32/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2029 - mean_absolute_error: 0.3639 - val_loss: 0.1631 - val_mean_absolute_error: 0.3153
# Epoch 33/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1970 - mean_absolute_error: 0.3579 - val_loss: 0.1547 - val_mean_absolute_error: 0.3078
# Epoch 34/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1919 - mean_absolute_error: 0.3525 - val_loss: 0.1477 - val_mean_absolute_error: 0.3014
# Epoch 35/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1874 - mean_absolute_error: 0.3477 - val_loss: 0.1411 - val_mean_absolute_error: 0.2954
# Epoch 36/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1836 - mean_absolute_error: 0.3436 - val_loss: 0.1354 - val_mean_absolute_error: 0.2901
# Epoch 37/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1802 - mean_absolute_error: 0.3401 - val_loss: 0.1307 - val_mean_absolute_error: 0.2859
# Epoch 38/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1774 - mean_absolute_error: 0.3371 - val_loss: 0.1266 - val_mean_absolute_error: 0.2821
# Epoch 39/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1749 - mean_absolute_error: 0.3346 - val_loss: 0.1228 - val_mean_absolute_error: 0.2786
# Epoch 40/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1728 - mean_absolute_error: 0.3323 - val_loss: 0.1198 - val_mean_absolute_error: 0.2756
# Epoch 41/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1710 - mean_absolute_error: 0.3303 - val_loss: 0.1167 - val_mean_absolute_error: 0.2725
# Epoch 42/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1695 - mean_absolute_error: 0.3286 - val_loss: 0.1146 - val_mean_absolute_error: 0.2703
# Epoch 43/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1683 - mean_absolute_error: 0.3271 - val_loss: 0.1123 - val_mean_absolute_error: 0.2676
# Epoch 44/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1672 - mean_absolute_error: 0.3257 - val_loss: 0.1104 - val_mean_absolute_error: 0.2656
# Epoch 45/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1663 - mean_absolute_error: 0.3245 - val_loss: 0.1090 - val_mean_absolute_error: 0.2640
# Epoch 46/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1656 - mean_absolute_error: 0.3234 - val_loss: 0.1076 - val_mean_absolute_error: 0.2625
# Epoch 47/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1650 - mean_absolute_error: 0.3225 - val_loss: 0.1064 - val_mean_absolute_error: 0.2610
# Epoch 48/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1645 - mean_absolute_error: 0.3217 - val_loss: 0.1056 - val_mean_absolute_error: 0.2602
# Epoch 49/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1641 - mean_absolute_error: 0.3211 - val_loss: 0.1047 - val_mean_absolute_error: 0.2591
# Epoch 50/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1637 - mean_absolute_error: 0.3205 - val_loss: 0.1039 - val_mean_absolute_error: 0.2579
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1039 - mean_absolute_error: 0.2579

# %%
plt.bar(x = range(len(train_df.columns)),
        height=linear.layers[0].kernel[:,0].numpy())
axis = plt.gca()
axis.set_xticks(range(len(train_df.columns)))
_ = axis.set_xticklabels(train_df.columns, rotation=90)

# %%
prediction_data = wide_window.make_dataset(test_df)
predictions = linear.predict(prediction_data)
predictions_original = (predictions * train_std['value']) + train_mean['value']
# Assuming you have trained the model and obtained predictions
wide_window.plot(model=linear, plot_col='value')



#first_sample_predictions = predictions[0]
# org=[]
# for d in first_sample_predictions:
#     val = d[0]
#     #predictions_original = (val * train_std) + train_mean
#     org.append(float(val))
# for o in org:
#     predictions_original = (o * train_std) + train_mean
#     print(predictions_original[0])
# Out:
# 5/5 [==============================] - 0s 2ms/step
